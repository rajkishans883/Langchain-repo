# %% [markdown]
# Build-in tools - DuckDuckGo Search using langchain

# %%
pip install -U langchain-community duckduckgo-search

# %%
pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.1 MB/s eta 0:00:00
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result = search_tool.invoke(" tell me about fifa world cup todays matches with timeing and country")
print(result)
# Out:
# 1 hour ago - This will be the first time the country competes under DR Congo. ^ Until 1992, the Czech Republic was part of Czechoslovakia, which competed in eight World Cup tournaments. Following its dissolution, the Czech Republic has qualified for the tournament for the second time as an independent nation, having previously debuted in 2006. ... ^ a b c d e f The winners of the UEFA playoffs and inter-confederation playoffs were not known at the time of the draw, as those matches were held on 26 and 31 March 2026. 4 hours ago - Spain vs Cape Verde begins at 9:30 PM IST today. On June 16, Belgium face Egypt at 12:30 AM IST, Uruguay take on Saudi Arabia at 3:30 AM IST, and Iran play New Zealand at 6:30 AM IST. 2 hours ago - Match Time shown in your local time. ... Diomande and Diallo hint at exciting road ahead for Côte d'IvoireDiomande and Diallo hint at exciting road ahead for Côte d'Ivoire · Spain embracing expectations ahead of World Cup openerSpain embracing expectations ahead o
# ...

# %%
pip install -U langchain-experimental
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 5.5 MB/s eta 0:00:00
# ...

# %%
#BUILD-IN Tools - Shell Tools

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
result = shell_tool.invoke("whomami")
print(result)
# Out:
# Executing command:
#  whomami
# /bin/sh: 1: whomami: not found
